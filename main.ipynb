# %% [markdown]
# ## House Price Prediction
#
# ### Dataset Information
#
# Dataset was obtained from kaggle through this link: https://www.kaggle.com/datasets/anmolkumar/house-price-prediction-challenge

# %%
import pandas as pd

train_dataset = pd.read_csv('./train.csv')

print(f"Dataset Head:\n\n{train_dataset.head(2)}\n\n")
print(f"Dataset Columns:\n{train_dataset.columns}")
# Out:
# Dataset Head:
#
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                   0     0        2       BHK  1300.236407
# 1    Dealer                   0     0        2       BHK  1275.000000
#
#    READY_TO_MOVE  RESALE                    ADDRESS  LONGITUDE   LATITUDE  \
# 0              1       1      Ksfc Layout,Bangalore  12.969910  77.597960
# 1              1       1  Vishweshwara Nagar,Mysore  12.274538  76.644605
#
#    TARGET(PRICE_IN_LACS)
# 0                   55.0
# 1                   51.0
#
#
# Dataset Columns:
# Index(['POSTED_BY', 'UNDER_CONSTRUCTION', 'RERA', 'BHK_NO.', 'BHK_OR_RK',
#        'SQUARE_FT', 'READY_TO_MOVE', 'RESALE', 'ADDRESS', 'LONGITUDE',
#        'LATITUDE', 'TARGET(PRICE_IN_LACS)'],
#       dtype='object')

# %%
## Check for missing value

print(f"Missing Value:\n{train_dataset.isna().sum()}")
# Out:
# Missing Value:
# POSTED_BY                0
# UNDER_CONSTRUCTION       0
# RERA                     0
# BHK_NO.                  0
# BHK_OR_RK                0
# SQUARE_FT                0
# READY_TO_MOVE            0
# RESALE                   0
# ADDRESS                  0
# LONGITUDE                0
# LATITUDE                 0
# TARGET(PRICE_IN_LACS)    0
# dtype: int64

# %%
# Define Outlier check function 

import numpy as np

def find_outliers_iqr(data):
    q1 = np.percentile(data, 25)
    q3 = np.percentile(data, 75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = data[(data < lower_bound) | (data > upper_bound)]
    return outliers

outlier_prone_features = ['BHK_NO.', 'SQUARE_FT', 'TARGET(PRICE_IN_LACS)']

# %%
# Check for outlier
for outline_prone_feature in outlier_prone_features:
    print(f"Outlier For {outline_prone_feature}:\n{len(find_outliers_iqr(train_dataset[outline_prone_feature]))}\n")
# Out:
# Outlier For BHK_NO.:
# 284
#
# Outlier For SQUARE_FT:
# 1635
#
# Outlier For TARGET(PRICE_IN_LACS):
# 3084

# %%
# Check data size before outlier deleteion
print(f"Data size before outlier deletion: {len(train_dataset)}")

# Delete Outliers
for outline_prone_feature in outlier_prone_features:
    train_dataset = train_dataset[~train_dataset[outline_prone_feature].isin(find_outliers_iqr(train_dataset[outline_prone_feature]))]

# Check data size after outlier deleteion
print(f"Data size after outlier deletion: {len(train_dataset)}")
# Out:
# Data size before outlier deletion: 29451
# Data size after outlier deletion: 25633

# %%
# Check for imbalance
from collections import Counter

imbalance_prone_features = ['POSTED_BY', 'BHK_OR_RK', 'ADDRESS']

for imbalance_prone_feature in imbalance_prone_features:
    print(f"{Counter(train_dataset[imbalance_prone_feature])}")
# Out:
# Counter({'Dealer': 14918, 'Owner': 10131, 'Builder': 584})
# Counter({'BHK': 25609, 'RK': 24})
 38, 'PAL,Surat': 38, 'Hebbal,Bangalore': 37, 'Sector-119 Noida,Noida': 37, 'Mulund (West),Lalitpur': 37, 'Kolshet Road,Maharashtra': 37, 'Patia,Bhubaneswar': 37, 'Sector 77 Faridabad,Faridabad': 36, 'Garia,Kolkata': 36, 'Balkum,Maharashtra': 36, 'Mira Road,Lalitpur': 36, 'Malad (West),Lalitpur': 36, 'Kharar,Mohali': 35, 'Keshav Nagar,Pune': 35, 'Bellandur,Bangalore': 35, 'Sector-100 Noida,Noida': 35, 'Sector-66A Mohali,Mohali': 34, 'Taloja,Mumbai': 34, 'Kandivali (East),Lalitpur': 34, 'Kasavanhalli,Bangalore': 34, 'Mira Road East,Mumbai': 34, 'Guduvancheri,Chennai': 34, 'Uttarahalli,Bangalore': 34, 'Sector-115 Mohali,Mohali': 33, 'Hennur Road,Bangalore': 33, 'E M Bypass,Kolkata': 33, 'Kharghar,Maharashtra': 33, 'Medavakkam,Chennai': 32, 'Sector-107 Noida,Noida': 32, 'Sector-70 Mohali,Mohali': 32, 'Dera Bassi,Chandigarh': 32, 'Sector-45 Noida,Noida': 32, 'Sector 75 Faridabad,Faridabad': 32, 'Vasna-Bhayli-Road,Vadodara': 32, 'Electronic City Phase II,Bangalore': 31, 'Manpada,Mumbai': 31, 'Sargasan,Gandhinagar': 31, 'Ahinsa Khand 1,Ghaziabad': 31, 'NH-8,Dharuhera': 31, 'Sector-88 Mohali,Mohali': 30, 'KR Puram,Bangalore': 30, 'Sushant Golf City,Lucknow': 30, 'Mulund (West),Mumbai': 30, 'Sodepur,Kolkata': 30, 'Gandhi Path,Jaipur': 30, 'Madhurawada,Visakhapatnam': 29, 'Chandapura,Bangalore': 29, 'Kanjur Marg (East),Mumbai': 29, 'Sector-50 Noida,Noida': 29, 'Nipania,Indore': 29, 'Sector 78 Faridabad,Faridabad': 29, 'Sholinganallur,Chennai': 29, 'Chhalera,Noida': 29, 'Sarjapur,Bangalore': 29, 'Sector-15 Bahadurgarh,Bahadurgarh': 29, 'Budigere,Bangalore': 28, 'Balkum,Mumbai': 28, 'Tathawade,Pune': 28, 'Katara Hills,Bhopal': 28, 'Begur Road, ...

# %%
# Copy Dataset

processed_train_df = train_dataset.copy()

# %%
# Create a new feature called city
processed_train_df['CITY'] = processed_train_df['ADDRESS'].apply(lambda x: x.split(',')[-1])

print(Counter(processed_train_df['CITY']))
# Out:
# Counter({'Bangalore': 3793, 'Lalitpur': 2120, 'Pune': 1811, 'Kolkata': 1582, 'Noida': 1578, 'Mumbai': 1396, 'Chennai': 1190, 'Maharashtra': 1079, 'Ghaziabad': 1057, 'Jaipur': 909, 'Chandigarh': 675, 'Faridabad': 618, 'Mohali': 498, 'Vadodara': 482, 'Surat': 379, 'Nagpur': 331, 'Lucknow': 312, 'Indore': 283, 'Gurgaon': 258, 'Bhubaneswar': 228, 'Bhopal': 211, 'Kochi': 178, 'Visakhapatnam': 169, 'Bhiwadi': 161, 'Goa': 141, 'Coimbatore': 134, 'Dehradun': 123, 'Ranchi': 117, 'Mangalore': 116, 'Gandhinagar': 114, 'Sonipat': 112, 'Palghar': 107, 'Secunderabad': 102, 'Guwahati': 89, 'Raipur': 88, 'Kanpur': 84, 'Jamshedpur': 84, 'Siliguri': 82, 'Rajkot': 81, 'Patna': 81, 'Agra': 79, 'Panchkula': 77, 'Vijayawada': 75, 'Aurangabad': 66, 'Jamnagar': 66, 'Raigad': 64, 'Dharuhera': 63, 'Durgapur': 55, 'Thrissur': 54, 'Gwalior': 53, 'Allahabad': 49, 'Meerut': 49, 'Bahadurgarh': 47, 'Anand': 46, 'Ernakulam': 44, 'Mysore': 43, 'Bharuch': 42, 'Valsad': 41, 'Kota': 41, 'Varanasi': 40, 'Ratnagiri': 40, 'Haridwar': 40, 'Bhilai': 38, 'Vapi': 37, 'Neemrana': 35, 'Asansol': 34, 'Jabalpur': 33, 'Jalandhar': 33, 'Kolhapur': 33, 'Udaipur': 33, 'Udupi': 32, 'Madurai': 32, 'Guntur': 32, 'Bhavnagar': 31, 'Hubli': 30, 'Dhanbad': 30, 'Amravati': 28, 'Ludhiana': 26, 'Panaji': 26, 'Jodhpur': 25, 'Ahmednagar': 24, 'Palakkad': 24, 'Nellore': 22, 'Solapur': 21, 'Bilaspur': 21, 'Sindhudurg': 21, 'Navsari': 21, 'Ajmer': 21, 'Aligarh': 21, 'Shimla': 20, 'Karjat': 20, 'Belgaum': 19, 'Margao': 19, 'Vizianagaram': 18, 'Rudrapur': 18, 'Kottayam': 17, 'Junagadh': 17, 'Pondicherry': 16, 'Tirupati': 16, 'Jalgaon': 16, 'Solan': 15, 'Karad': 14, 'Mathura': 14, 'Kannur': 12, 'Kakinada': 12, 'Chandrapur': 12, 'Alwar': 11, 'Wardha': 10, 'Durg': 10, 'Amritsar': 10, 'Nainital': 10, 'Kanchipuram': 10, 'Puri': 10, 'Latur': 9, 'Hazaribagh': 9, 'Karnal': 9, 'Gandhidham': 9, 'Akola': 9, 'Bareilly': 9, 'Tirunelveli': 8, 'Cuttack': 8, 'Tenali': 8, 'Rohtak': 8, 'Berhampur': 7, 'Jhansi': 7, 'Eluru': 7, 'Ongole': 7, 'Bardhaman': 7, 'Moradabad': 7, 'Rewari': 7, 'Morbi': 6, 'Muzaffarpur': 6, 'Kollam': 6, 'Palwal': 6, 'Anantapur': 5, 'Gaya': 5, 'Dharwad': 5, 'Haldwani': 5, 'Bokaro': 5, 'Bhimavaram': 5, 'Ujjain': 5, 'Shirdi': 5, 'Nadiad': 5, 'Gulbarga': 5, 'Raigarh': 5, 'Hosur': 4, 'Dhule': 4, 'Panipat': 4, 'Warangal': 4, 'Bhagalpur': 4, 'Godhra': 4, 'Kharagpur': 4, 'Thanjavur': 4, 'Nanded': 4, 'Jammu': 4, 'Roorkee': 3, 'Hoshangabad': 3, 'Salem': 3, 'Jalna': 3, 'Bhandara': 3, 'Dalhousie': 3, 'Rishikesh': 3, 'Hapur': 3, 'Thoothukudi': 3, 'Gadhinglaj': 3, 'Srikakulam': 3, 'Porbandar': 3, 'Pathanamthitta': 3, 'Sikar': 3, 'Deoghar': 2, 'Satna': 2, 'Kotdwara': 2, 'Patiala': 2, 'Gurdaspur': 2, 'Kadi': 2, 'Jind': 2, 'Ooty': 2, 'Barabanki': 2, 'Erode': 2, 'Kadapa': 2, 'Kurnool': 2, 'Yavatmal': 2, 'Bikaner': 2, 'Rewa': 2, 'Rourkela': 2, 'Bankura': 2, 'Arrah': 2, 'Karwar': 2, 'Baddi': 2, 'Haldia': 2, 'Ottapalam': 1, 'Hassan': 1, 'Jagdalpur': 1, 'Jhunjhunu': 1, 'Hajipur': 1, 'Pudukkottai': 1, 'Rajpura': 1, 'Siddipet': 1, 'Darbhanga': 1, 'Agartala': 1, 'Osmanabad': 1, 'Bhiwani': 1, 'Jharsuguda': 1, 'Amroha': 1, 'Sabarkantha': 1, 'Harda': 1, 'Karaikudi': 1, 'Srinagar': 1, 'Midnapore': 1, 'Rayagada': 1, 'Banswara': 1, 'Pali': 1, 'Hathras': 1, 'Balasore': 1, 'Chhindwara': 1, 'Nagaur': 1, 'Palanpur': 1, 'Kurukshetra': 1, 'Dibrugarh': 1, 'Machilipatnam': 1, 'Idukki': 1, 'Korba': 1, 'Ambala': 1, 'Silchar': 1, 'Nagaon': 1, 'Dahod': 1, 'Nagapattinam': 1, 'Angul': 1, 'Darjeeling': 1, 'Raisen': 1, 'Hoshiarpur': 1, 'Gadarwara': 1, 'Jajpur': 1, 'Chittoor': 1, 'Faizabad': 1, 'Malappuram': 1, 'Betul': 1, 'Surendranagar': 1, 'Visnagar': 1, 'Rajnandgaon': 1, 'Raichur': 1, 'Sambalpur': 1, 'Gondia': 1, 'Vellore': 1, 'Bharatpur': 1, 'Bhuj': 1, 'Siwan': 1, 'Washim': 1})

# %%
# Drop Address
processed_train_df = processed_train_df.drop('ADDRESS', axis=1)

# %%
# Label Encoding
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

features_to_encode = ['POSTED_BY', 'BHK_OR_RK', 'CITY']

for feature_to_encode in features_to_encode:
    processed_train_df[feature_to_encode] = le.fit_transform(processed_train_df[feature_to_encode])

# %%
# Normalize and split the data

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

features = ['POSTED_BY', 'UNDER_CONSTRUCTION', 'RERA', 'BHK_NO.', 'BHK_OR_RK',
       'SQUARE_FT', 'READY_TO_MOVE', 'RESALE', 'CITY', 'LONGITUDE',
       'LATITUDE']

target = 'TARGET(PRICE_IN_LACS)'

x = processed_train_df[features]
y = processed_train_df[target]

scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)

x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42)

# %%
# Random forest regressor
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor

# Build Model
rf_regressor = RandomForestRegressor(n_estimators=150, max_depth=10, min_samples_split=2)
rf_regressor.fit(x_train, y_train)

# Make predictions
rf_pred = rf_regressor.predict(x_test)

# Calculate MAE
rf_mae = mean_absolute_error(y_test, rf_pred)
print(f"Random Forest MAE: {rf_mae:.2f}")

# Overfit Check
rf_train_pred = rf_regressor.predict(x_train)
rf_train_mae = mean_absolute_error(y_train, rf_train_pred)

print(f"Random Forest MAE for Train Data: {rf_train_mae:.2f}")
# Out:
# Random Forest MAE: 13.60
# Random Forest MAE for Train Data: 12.11
